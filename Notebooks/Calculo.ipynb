# %% [markdown]
# # Cálculo.
#
# Ejercicios 1 a 6 del apartado 1.26 Libro de Cálculo de Tom Apostol página

# %%
from sympy import *
init_printing()
x = Symbol('x')
datos=[
    (x**2,0,4),
    (x**2,-3,3),
    (4*x**3,0,2),
    (4*x**3,-2,2),
    (5*x**4,0,1),
    (5*x**4,-1,1)
]
for expr,a,b in datos:
    integral=Integral(expr,(x,a,b))
    resultado=integral.doit()
    display(Eq(integral,resultado))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from sympy import *
#       2 init_printing()
#       3 x = Symbol('x')
#       4 datos=[
#
# ModuleNotFoundError: No module named 'sympy'
